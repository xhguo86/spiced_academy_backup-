# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.linear_model import LinearRegression

# from statsmodels.api import OLS, add_constant, qqplot
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.graphics.tsaplots import plot_pacf

# %%
df = pd.read_csv('arma_process.csv')
df
# Out:
#      remainder
# 0     1.668068
# 1     3.594771
# 2     4.674503
# 3     3.665661
# 4     3.496006
# ..         ...
# 127   3.277818
# 128   3.617415
# 129   4.035193
# 130   3.532804
# 131   3.810848
#
# [132 rows x 1 columns]

# %%
df.plot()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df)

# %%
selected_order = ar_select_order(df, maxlag=10)
selected_order

# %%
from statsmodels.tsa.ar_model import AutoReg

ar_model = AutoReg(endog=df['remainder'], lags=5).fit()

# %%
# Look at the model summary
ar_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              remainder   No. Observations:                  132
# Model:                     AutoReg(5)   Log Likelihood                -176.858
# Method:               Conditional MLE   S.D. of innovations              0.974
# Date:                Thu, 29 Apr 2021   AIC                              0.058
# Time:                        10:19:40   BIC                              0.214
# Sample:                             5   HQIC                             0.121
#                                   132
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept       -0.0529      0.088     -0.602      0.547      -0.225       0.119
# remainder.L1     1.5343      0.089     17.251      0.000       1.360       1.709
# remainder.L2    -1.1759      0.160     -7.356      0.000      -1.489      -0.863
# remainder.L3     0.8209      0.176      4.665      0.000       0.476       1.166
# remainder.L4    -0.3348      0.159     -2.104      0.035      -0.647      -0.023
# remainder.L5     0.0185      0.088      0.210      0.834      -0.155       0.192
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0064           -1.3993j            1.3993           -0.2493
# AR.2            0.0064           +1.3993j            1.3993            0.2493
# AR.3            1.3055           -0.2836j            1.3360           -0.0340
# AR.4            1.3055           +0.2836j            1.3360            0.0340
# AR.5           15.4334           -0.0000j           15.4334           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
df.plot()

# %%
plt.plot()
