# %% [markdown]
# Download the web page https://en.wikipedia.org/wiki/Berlin
# Print the status code of the request
# Print the size of the HTML document in characters
# Extract all hyperlinks (<a href="...">)
# Remove all HTML tags
# Count how many times the word 'Berlin' occurs
# Count the total number of words on the page

# %%
import re
import requests
import nltk
from bs4 import BeautifulSoup


url = 'https://en.wikipedia.org/wiki/Berlin'

# %%
response = requests.get(url)

# %%
html = response.text

# %%
import sys

# %%
sys.getsizeof(html)
len(html)
# Out:
# 920422

# %%
response.status_code
# Out:
# 200

# %%
soup =  BeautifulSoup(html)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Berlin - Wikipedia</title>
# ...

# %%
import re
h_links =  re.findall(''' href="[^"]*"''',html)
h_links
# Out:
# [' href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.kartographer.style%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cmediawiki.page.gallery.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"',
#  ' href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"',
#  ' href="//upload.wikimedia.org"',
#  ' href="//en.m.wikipedia.org/wiki/Berlin"',
#  ' href="/w/index.php?title=Berlin&amp;action=edit"',
#  ' href="/w/index.php?title=Berlin&amp;action=edit"',
#  ' href="/static/apple-touch/wikipedia.png"',
#  ' href="/static/favicon/wikipedia.ico"',
#  ' href="/w/opensearch_desc.php"',
#  ' href="//en.wikipedia.org/w/api.php?action=rsd"',
#  ' href="//creativecommons.org/licenses/by-sa/3.0/"',
#  ' href="https://en.wikipedia.org/wiki/Berlin"',
#  ' href="//login.wikimedia.org"',
#  ' href="//meta.wikimedia.org"',
#  ' href="#mw-head"',
# ...

# %%
s = soup.text
s
# Out:
# '\n\n\nBerlin - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBerlin\n\nFrom Wikipedia, the free encyclopedia\n\n\n\nJump to navigation\nJump to search\nCapital and largest city of Germany\nThis article is about the German city. For other uses, see Berlin (disambiguation).\n\n\nPlace in GermanyBerlinCapital city, state and municipality\nFrom top: view with Nicholas\' Quarter, Rotes Rathaus, and the Television Tower; Brandenburg Gate; Berlin Cathedral; Charlottenburg Palace; Berlin Victory Column; Oberbaum Bridge; Potsdam Square; Gendarmenmarkt\nFlagCoat of armsBerlinLocation within GermanyShow map of GermanyBerlinBerlin (Europe)Show map of EuropeCoordinates: 52°31′12″N 13°24′18″E\ufeff / \ufeff52.52000°N 13.40500°E\ufeff / 52.52000; 13.40500Coordinates: 52°31′12″N 13°24′18″E\ufeff / \ufeff52.52000°N 13.40500°E\ufeff / 52.52000; 13.40500Country\xa0GermanyStateBerlinGovernment\xa0•\xa0BodyAbgeordnetenhaus of Berlin\xa0•\xa0Governing MayorMichael Müller (S
# ...

# %%
len(re.findall('Berlin',s))
# Out:
# 737

# %%
s=[]
songs = soup.find_all('a')
for i in songs:
        s.append(i.text)

s
# Out:
# ['',
#  'Jump to navigation',
#  'Jump to search',
#  'Berlin (disambiguation)',
#  'Capital city',
#  'state',
#  'municipality',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "Nicholas' Quarter",
#  'Rotes Rathaus',
#  'Television Tower',
#  'Brandenburg Gate',
#  'Berlin Cathedral',
#  'Charlottenburg Palace',
#  'Berlin Victory Column',
#  'Oberbaum Bridge',
#  'Potsdam Square',
#  'Gendarmenmarkt',
#  '',
#  'Flag',
#  '',
#  'Coat of arms',
#  '',
#  '',
#  'Germany',
#  '',
#  '52°31′12″N 13°24′18″E\ufeff / \ufeff52.52000°N 13.40500°E\ufeff / 52.52000; 13.40500',
#  'Coordinates',
#  '52°31′12″N 13°24′18″E\ufeff / \ufeff52.52000°N 13.40500°E\ufeff / 52.52000; 13.40500',
#  'Country',
#  'Germany',
#  'State',
#  'Abgeordnetenhaus of Berlin',
#  'Governing Mayor',
#  'Michael Müller',
#  'SPD',
#  '[1]',
#  '[2]',
#  'Urban',
#  '[3]',
#  'Metro',
#  '[4]',
#  'Demonyms',
#  'Time zone',
#  'UTC+01:00',
#  'CET',
#  'DST',
#  'UTC+02:00',
#  'CEST',
# ...

# %%
s=[]
songs = soup.find_all('a')
for i in songs:
        s.append(i.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-1eb81018d87b> in <module>
# ----> 1 len(re.findall('Berlin',h_links.text))
#
# AttributeError: 'list' object has no attribute 'text'
